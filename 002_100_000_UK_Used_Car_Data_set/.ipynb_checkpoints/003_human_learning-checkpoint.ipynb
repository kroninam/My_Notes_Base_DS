# %%
import numpy as np
import pandas as pd

# %%
# https://www.kaggle.com/datasets/abdelrahmankhalil/100000-uk-used-car-data-set

# %%
import zipfile
archive = 'archive.zip'
with zipfile.ZipFile(archive, 'r') as zip_file:
    zip_file.extractall('unzipped_archive')

# %%
df = pd.read_csv('unzipped_archive/bmw.csv')

# %%
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# 4             3.0
# ...           ...
# 10776         2.0
# 10777         2.0
# 10778         2.0
# 10779         2.0
# 10780         2.0
#
# [10781 rows x 9 columns]

# %%
# проверка на пропуски (если пропуски есть - думаем что с этим делать)
df.isna().mean()
# Out:
# model           0.0
# year            0.0
# price           0.0
# transmission    0.0
# mileage         0.0
# fuelType        0.0
# tax             0.0
# mpg             0.0
# engineSize      0.0
# dtype: float64

# %% [markdown]
# # Человеческое обучение - это создание алгоритма вручную

# %%
Мы как люди - будем смотреть на данные и вырабатывать алгоритм.

Алгоритм определения цены по параметрам автомобиля, которые есть в df.

Выработка неких правил по которым мы сможем определять цену автомобиля.

# %%
Прежде чем анализировать данные - надо разбить выборку на две части:

# %% [markdown]
# ## Обучающая и тестовая выборка (train & test)

# %%
from sklearn.model_selection import train_test_split

# по умолчанию train_size = 0.75, (test = 0.25)

# по умолчанию выборки train и test получаются всегда разные при их определении, выбираются случайно

# но выборку можно захолдить, передав парамтетр random_state = 42

train, test = train_test_split(df, train_size = 0.75)

# %%
train
# Out:
#            model  year  price transmission  mileage fuelType  tax    mpg  \
# 7328    3 Series  2019  21985    Semi-Auto     6659   Diesel  150   55.4
# 7115    4 Series  2014  16995    Semi-Auto    25276   Diesel  145   56.5
# 10587   5 Series  2018  26450    Automatic    16455   Petrol  145   37.7
# 8885    2 Series  2015   7395       Manual   100230   Diesel   20   68.9
# 8280    3 Series  2016  15300    Automatic    46626   Hybrid    0  134.5
# ...          ...   ...    ...          ...      ...      ...  ...    ...
# 5465    1 Series  2017  14500       Manual    13681   Diesel  145   65.7
# 9944    5 Series  2017  15995    Automatic    59069   Diesel   30   68.9
# 10444   3 Series  2017  12600       Manual    44596   Petrol  150   48.7
# 6937    1 Series  2019  16995    Automatic     9399   Diesel  145   70.6
# 10015         M4  2018  36440    Automatic    16000   Petrol  150   34.0
#
#        engineSize
# 7328          2.0
# 7115          2.0
# 10587         2.0
# 8885          2.0
# 8280          2.0
# ...           ...
# 5465          2.0
# 9944          2.0
# 10444         2.0
# 6937          2.0
# 10015         3.0
#
# [8085 rows x 9 columns]

# %%
test
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 615     5 Series  2015  11450       Manual    60529   Diesel   30  65.7
# 4284    1 Series  2019  21490    Semi-Auto     7801   Petrol  145  47.9
# 1720    3 Series  2019  19965    Semi-Auto    14153   Diesel  145  64.2
# 1358    3 Series  2019  34790    Automatic      123   Diesel  145  50.4
# 8981    1 Series  2013   9999       Manual    48279   Petrol  145  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 5352    2 Series  2019  21950       Manual       10   Diesel  145  64.2
# 7996    1 Series  2019  15199       Manual     8807   Petrol  145  53.3
# 8034    1 Series  2015   8999       Manual    59828   Diesel   20  72.4
# 655     1 Series  2017  13998       Manual    33094   Diesel   20  72.4
# 10628   5 Series  2019  23000    Automatic     9420   Petrol  145  50.4
#
#        engineSize
# 615           2.0
# 4284          2.0
# 1720          2.0
# 1358          2.0
# 8981          1.6
# ...           ...
# 5352          2.0
# 7996          1.5
# 8034          1.5
# 655           1.5
# 10628         2.0
#
# [2696 rows x 9 columns]

# %% [markdown]
# ## Анализ данных

# %%
# проверка на пропуски выборки train

train.isna().mean()
# Out:
# model           0.0
# year            0.0
# price           0.0
# transmission    0.0
# mileage         0.0
# fuelType        0.0
# tax             0.0
# mpg             0.0
# engineSize      0.0
# dtype: float64

# %%
train
# Out:
#            model  year  price transmission  mileage fuelType  tax    mpg  \
# 7328    3 Series  2019  21985    Semi-Auto     6659   Diesel  150   55.4
# 7115    4 Series  2014  16995    Semi-Auto    25276   Diesel  145   56.5
# 10587   5 Series  2018  26450    Automatic    16455   Petrol  145   37.7
# 8885    2 Series  2015   7395       Manual   100230   Diesel   20   68.9
# 8280    3 Series  2016  15300    Automatic    46626   Hybrid    0  134.5
# ...          ...   ...    ...          ...      ...      ...  ...    ...
# 5465    1 Series  2017  14500       Manual    13681   Diesel  145   65.7
# 9944    5 Series  2017  15995    Automatic    59069   Diesel   30   68.9
# 10444   3 Series  2017  12600       Manual    44596   Petrol  150   48.7
# 6937    1 Series  2019  16995    Automatic     9399   Diesel  145   70.6
# 10015         M4  2018  36440    Automatic    16000   Petrol  150   34.0
#
#        engineSize
# 7328          2.0
# 7115          2.0
# 10587         2.0
# 8885          2.0
# 8280          2.0
# ...           ...
# 5465          2.0
# 9944          2.0
# 10444         2.0
# 6937          2.0
# 10015         3.0
#
# [8085 rows x 9 columns]

# %%
# делаем предположение, что чем новее машина - тем она дороже. Так подсказывает опыт

# %%
# посмотрим на распеределение величины price:

# это распределение с жирным хвостом - потому что хотя хвост и тонкий, однако там находятся жирные значения до 120 000

train['price'].hist(edgecolor = 'black')
# Out:
# <Axes: >

# %%
# распределение понятно. теперь посмотрим на цифры:

df['price'].describe()
# Out:
# count     10781.000000
# mean      22733.408867
# std       11415.528189
# min        1200.000000
# 25%       14950.000000
# 50%       20462.000000
# 75%       27940.000000
# max      123456.000000
# Name: price, dtype: float64

# %%
# понять зависимость между price и year поможет СВОДНИК - главный инструмент DS

train.groupby('year')['price'].agg(['count', 'mean', 'median']).plot()
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# ## BaseLine

# %%
# Перед тем как делать алгоритм нужно посчитать так назвыаемый BaseLine

# это исходная точка

# это то качество модели, та ошибка модели или алгоритма от которго мы будем отталкиваться.
# если мы не можем сделать лучше чем Baseline - то смысла в нашей работе не будет.


# Можно всем машинам, когда они поступают задавать одну цену: train['price'].mean()

# но на сколько хорош будет этот алгоритм??

# %%
# Наш Baseline - это предположение, что цены для всех машин можно задавать как среднее значение цены по выборке

# %%
train['price'].mean()
# Out:
# 22778.881014223873

# %%
# делаем новую колонку в train и задаем ей значения среднего:

train['price_pred_mean'] = train['price'].mean()

# %%
train
# Out:
#            model  year  price transmission  mileage fuelType  tax    mpg  \
# 7328    3 Series  2019  21985    Semi-Auto     6659   Diesel  150   55.4
# 7115    4 Series  2014  16995    Semi-Auto    25276   Diesel  145   56.5
# 10587   5 Series  2018  26450    Automatic    16455   Petrol  145   37.7
# 8885    2 Series  2015   7395       Manual   100230   Diesel   20   68.9
# 8280    3 Series  2016  15300    Automatic    46626   Hybrid    0  134.5
# ...          ...   ...    ...          ...      ...      ...  ...    ...
# 5465    1 Series  2017  14500       Manual    13681   Diesel  145   65.7
# 9944    5 Series  2017  15995    Automatic    59069   Diesel   30   68.9
# 10444   3 Series  2017  12600       Manual    44596   Petrol  150   48.7
# 6937    1 Series  2019  16995    Automatic     9399   Diesel  145   70.6
# 10015         M4  2018  36440    Automatic    16000   Petrol  150   34.0
#
#        engineSize  price_pred_mean
# 7328          2.0     22778.881014
# 7115          2.0     22778.881014
# 10587         2.0     22778.881014
# 8885          2.0     22778.881014
# 8280          2.0     22778.881014
# ...           ...              ...
# 5465          2.0     22778.881014
# 9944          2.0     22778.881014
# 10444         2.0     22778.881014
# 6937          2.0     22778.881014
# 10015         3.0     22778.881014
#
# [8085 rows x 10 columns]

# %%
# рассчитываем ошибку err как разницу между средней ценой и ценой каждого кейса
# получаем значение ошибки с плюсом или минусом - задаем новый столбец err

train['err'] = train['price_pred_mean'] - train['price']

# %%
train
# Out:
#            model  year  price transmission  mileage fuelType  tax    mpg  \
# 7328    3 Series  2019  21985    Semi-Auto     6659   Diesel  150   55.4
# 7115    4 Series  2014  16995    Semi-Auto    25276   Diesel  145   56.5
# 10587   5 Series  2018  26450    Automatic    16455   Petrol  145   37.7
# 8885    2 Series  2015   7395       Manual   100230   Diesel   20   68.9
# 8280    3 Series  2016  15300    Automatic    46626   Hybrid    0  134.5
# ...          ...   ...    ...          ...      ...      ...  ...    ...
# 5465    1 Series  2017  14500       Manual    13681   Diesel  145   65.7
# 9944    5 Series  2017  15995    Automatic    59069   Diesel   30   68.9
# 10444   3 Series  2017  12600       Manual    44596   Petrol  150   48.7
# 6937    1 Series  2019  16995    Automatic     9399   Diesel  145   70.6
# 10015         M4  2018  36440    Automatic    16000   Petrol  150   34.0
#
#        engineSize  price_pred_mean           err       err_abs
# 7328          2.0     22778.881014    793.881014    793.881014
# 7115          2.0     22778.881014   5783.881014   5783.881014
# 10587         2.0     22778.881014  -3671.118986   3671.118986
# 8885          2.0     22778.881014  15383.881014  15383.881014
# 8280          2.0     22778.881014   7478.881014   7478.881014
# ...           ...              ...           ...           ...
# 5465          2.0     22778.881014   8278.881014   8278.881014
# 9944          2.0     22778.881014   6783.881014   6783.881014
# 10444         2.0     22778.881014  10178.881014  10178.881014
# 6937          2.0     22778.881014   5783.881014   5783.881014
# 10015         3.0     22778.881014 -13661.118986  13661.118986
#
# [8085 rows x 12 columns]

# %%
# все ошибки берем по модулю, делаем новый столбец с абсолютными:

# это absolute error

train['err_abs'] = (abs(train['err']))

# %%
train
# Out:
#            model  year  price transmission  mileage fuelType  tax    mpg  \
# 7328    3 Series  2019  21985    Semi-Auto     6659   Diesel  150   55.4
# 7115    4 Series  2014  16995    Semi-Auto    25276   Diesel  145   56.5
# 10587   5 Series  2018  26450    Automatic    16455   Petrol  145   37.7
# 8885    2 Series  2015   7395       Manual   100230   Diesel   20   68.9
# 8280    3 Series  2016  15300    Automatic    46626   Hybrid    0  134.5
# ...          ...   ...    ...          ...      ...      ...  ...    ...
# 5465    1 Series  2017  14500       Manual    13681   Diesel  145   65.7
# 9944    5 Series  2017  15995    Automatic    59069   Diesel   30   68.9
# 10444   3 Series  2017  12600       Manual    44596   Petrol  150   48.7
# 6937    1 Series  2019  16995    Automatic     9399   Diesel  145   70.6
# 10015         M4  2018  36440    Automatic    16000   Petrol  150   34.0
#
#        engineSize  price_pred_mean           err       err_abs
# 7328          2.0     22778.881014    793.881014    793.881014
# 7115          2.0     22778.881014   5783.881014   5783.881014
# 10587         2.0     22778.881014  -3671.118986   3671.118986
# 8885          2.0     22778.881014  15383.881014  15383.881014
# 8280          2.0     22778.881014   7478.881014   7478.881014
# ...           ...              ...           ...           ...
# 5465          2.0     22778.881014   8278.881014   8278.881014
# 9944          2.0     22778.881014   6783.881014   6783.881014
# 10444         2.0     22778.881014  10178.881014  10178.881014
# 6937          2.0     22778.881014   5783.881014   5783.881014
# 10015         3.0     22778.881014 -13661.118986  13661.118986
#
# [8085 rows x 12 columns]

# %%
# это метрика - Mean absolute error (MAE). 

# MAE измеряет среднее абсолютное отклонение между прогнозируемыми и фактическими значениями. 
# Она вычисляется как сумма абсолютных разностей между прогнозами и фактическими значениями, 
# деленная на общее количество прогнозов. MAE показывает, насколько близко прогнозируемые 
# значения к фактическим значениям, без учета направления отклонений. 
# Чем меньше значение MAE, тем лучше качество модели.

train['err_abs'].mean()
# Out:
# 8469.959297614365

# %%
# посчитаем ошибку в процентах - на сколько в процентах мы ошибились при определении цены, относительно правильной цены:

# используя среднее значение:

# получаем относительную ошибку = absolute percentage error 

train['err_abs_pct'] = train['err_abs'] / train['price']

# %%
train
# Out:
#            model  year  price transmission  mileage fuelType  tax    mpg  \
# 7328    3 Series  2019  21985    Semi-Auto     6659   Diesel  150   55.4
# 7115    4 Series  2014  16995    Semi-Auto    25276   Diesel  145   56.5
# 10587   5 Series  2018  26450    Automatic    16455   Petrol  145   37.7
# 8885    2 Series  2015   7395       Manual   100230   Diesel   20   68.9
# 8280    3 Series  2016  15300    Automatic    46626   Hybrid    0  134.5
# ...          ...   ...    ...          ...      ...      ...  ...    ...
# 5465    1 Series  2017  14500       Manual    13681   Diesel  145   65.7
# 9944    5 Series  2017  15995    Automatic    59069   Diesel   30   68.9
# 10444   3 Series  2017  12600       Manual    44596   Petrol  150   48.7
# 6937    1 Series  2019  16995    Automatic     9399   Diesel  145   70.6
# 10015         M4  2018  36440    Automatic    16000   Petrol  150   34.0
#
#        engineSize  price_pred_mean           err       err_abs  err_abs_pct
# 7328          2.0     22778.881014    793.881014    793.881014     0.036110
# 7115          2.0     22778.881014   5783.881014   5783.881014     0.340328
# 10587         2.0     22778.881014  -3671.118986   3671.118986     0.138795
# 8885          2.0     22778.881014  15383.881014  15383.881014     2.080308
# 8280          2.0     22778.881014   7478.881014   7478.881014     0.488816
# ...           ...              ...           ...           ...          ...
# 5465          2.0     22778.881014   8278.881014   8278.881014     0.570957
# 9944          2.0     22778.881014   6783.881014   6783.881014     0.424125
# 10444         2.0     22778.881014  10178.881014  10178.881014     0.807848
# 6937          2.0     22778.881014   5783.881014   5783.881014     0.340328
# 10015         3.0     22778.881014 -13661.118986  13661.118986     0.374893
#
# [8085 rows x 13 columns]

# %%
# теперь считаем среднее по этой ошибке:

# это метрика - mean absolute percentage error (MAPE) 

# MAPE измеряет среднее абсолютное отклонение между прогнозируемыми 
# и фактическими значениями, выраженное в процентах от фактических значений. 
# Эта метрика также позволяет оценить точность модели, но в отличие от 
# MAE она учитывает относительные отклонения между прогнозами и 
# фактическими значениями. Метрика MAPE может быть полезна в случаях, 
# когда важно оценить точность прогнозов с учетом масштаба данных. 
# Также стоит отметить, что MAPE может быть неопределенной (или бесконечной), 
# если фактические значения равны нулю. 
# Чем меньше значение MAPE, тем лучше качество модели.

# это наш Baseline - то есть максимальная ошибка которая может быть и ниже нее нет смысла считать что-то

train['err_abs_pct'].mean()
# Out:
# 0.47902844403495787

# %%
# будет ли прогноз лучше если вместо среднего взять медиану??

# об этом скажут метрики MAE и MAPE. Чем они меньше - тем лучше модель.

train['price'].median()
# Out:
# 20491.0

# %%
# делаем новую колонку в train и задаем ей значения медианы:

train['price_pred_median'] = train['price'].median()

# %%
train
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 1899    3 Series  2015  18555    Semi-Auto    51416   Diesel  145  53.3
# 10001         M2  2018  23495    Automatic    17000   Petrol  145  39.8
# 4250          X1  2019  25000       Manual      110   Diesel  145  60.1
# 5645          Z4  2019  43995    Automatic     4401   Petrol  145  33.2
# 8235          X1  2018  22470    Automatic     9365   Petrol  145  44.8
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 1746    3 Series  2019  25560    Semi-Auto     3000   Diesel  145  62.8
# 9562    1 Series  2017  10999       Manual    46147   Diesel    0  83.1
# 873     2 Series  2019  22500    Semi-Auto     5058   Petrol  145  50.4
# 5354    3 Series  2019  28450    Semi-Auto    13998   Petrol  145  42.2
# 9453    2 Series  2016  11299    Automatic    49981   Diesel   20  72.4
#
#        engineSize  price_pred_mean          err      err_abs  err_abs_pct  \
# 1899          3.0      22786.96945   4231.96945   4231.96945     0.228077
# 10001         3.0      22786.96945   -708.03055    708.03055     0.030135
# 4250          2.0      22786.96945  -2213.03055   2213.03055     0.088521
# 5645          3.0      22786.96945 -21208.03055  21208.03055     0.482055
# 8235          2.0      22786.96945    316.96945    316.96945     0.014106
# ...           ...              ...          ...          ...          ...
# 1746          2.0      22786.96945  -2773.03055   2773.03055     0.108491
# 9562          1.5      22786.96945  11787.96945  11787.96945     1.071731
# 873           2.0      22786.96945    286.96945    286.96945     0.012754
# 5354          2.0      22786.96945  -5663.03055   5663.03055     0.199052
# 9453          1.5      22786.96945  11487.96945  11487.96945     1.016724
#
#        price_pred_median
# 1899             20498.0
# 10001            20498.0
# 4250             20498.0
# 5645             20498.0
# 8235             20498.0
# ...                  ...
# 1746             20498.0
# 9562             20498.0
# 873              20498.0
# 5354             20498.0
# 9453             20498.0
#
# [8085 rows x 14 columns]

# %%
# получаем ошибку относительно медианной цены и реальной цены:

train['err_median'] = train['price_pred_median'] - train['price']

# %%
# получаем модуль этой ошибки

np.mean(abs(train['err_median']))
# Out:
# 8256.885590599877

# %%
# создаем столбец для ошибки

train['err_abs_median'] = (abs(train['err_median']))

# %%
# считаем среднее ошибки (MAE)

train['err_abs_median'].mean()
# Out:
# 8256.885590599877

# %%
# посчитаем ошибку в процентах - на сколько в процентах мы ошибились при определении цены, относительно правильной цены:

# MAPE

# используя медианное значение:

train['err_abs_pct_median'] = train['err_abs_median'] / train['price']

# %%
np.mean(train['err_abs_pct_median'])
# Out:
# 0.43098435175881716

# %%
# Всё то же самое можно проделать с помощью специальных функций sklearn:

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# для среднего:
print(mean_absolute_error(train['price'], train['price_pred_mean']))
print(mean_absolute_percentage_error(train['price'], train['price_pred_mean']))

print('*'*20)

# для медианы:
print(mean_absolute_error(train['price'], train['price_pred_median']))
print(mean_absolute_percentage_error(train['price'], train['price_pred_median']))


# сравнивая абсолютную ошибку (в фунтах цены от каждой продажи) и ошибку в процентах - можно выбрать лучшую метрику
# в данном случае - для данной модели - медиана дает меньшее значение ошибки на 6%. Значит используем медиану.
# Out:
# 8469.959297614365
# 0.48914091953802397
# ********************
# 8256.885590599877
# 0.43098435175881716

# %%
# теперь проверим работу алгоритма (модели) на тестовой выборке: (рассчитаем MAE и MAPE и оценим их)

test
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 615     5 Series  2015  11450       Manual    60529   Diesel   30  65.7
# 4284    1 Series  2019  21490    Semi-Auto     7801   Petrol  145  47.9
# 1720    3 Series  2019  19965    Semi-Auto    14153   Diesel  145  64.2
# 1358    3 Series  2019  34790    Automatic      123   Diesel  145  50.4
# 8981    1 Series  2013   9999       Manual    48279   Petrol  145  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 5352    2 Series  2019  21950       Manual       10   Diesel  145  64.2
# 7996    1 Series  2019  15199       Manual     8807   Petrol  145  53.3
# 8034    1 Series  2015   8999       Manual    59828   Diesel   20  72.4
# 655     1 Series  2017  13998       Manual    33094   Diesel   20  72.4
# 10628   5 Series  2019  23000    Automatic     9420   Petrol  145  50.4
#
#        engineSize
# 615           2.0
# 4284          2.0
# 1720          2.0
# 1358          2.0
# 8981          1.6
# ...           ...
# 5352          2.0
# 7996          1.5
# 8034          1.5
# 655           1.5
# 10628         2.0
#
# [2696 rows x 9 columns]

# %%
# добавляем колонку в test - в которой указваем медиану из набора train !

test['price_pred_median'] = train['price'].median()

# %%
test
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 615     5 Series  2015  11450       Manual    60529   Diesel   30  65.7
# 4284    1 Series  2019  21490    Semi-Auto     7801   Petrol  145  47.9
# 1720    3 Series  2019  19965    Semi-Auto    14153   Diesel  145  64.2
# 1358    3 Series  2019  34790    Automatic      123   Diesel  145  50.4
# 8981    1 Series  2013   9999       Manual    48279   Petrol  145  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 5352    2 Series  2019  21950       Manual       10   Diesel  145  64.2
# 7996    1 Series  2019  15199       Manual     8807   Petrol  145  53.3
# 8034    1 Series  2015   8999       Manual    59828   Diesel   20  72.4
# 655     1 Series  2017  13998       Manual    33094   Diesel   20  72.4
# 10628   5 Series  2019  23000    Automatic     9420   Petrol  145  50.4
#
#        engineSize  price_pred_median
# 615           2.0            20491.0
# 4284          2.0            20491.0
# 1720          2.0            20491.0
# 1358          2.0            20491.0
# 8981          1.6            20491.0
# ...           ...                ...
# 5352          2.0            20491.0
# 7996          1.5            20491.0
# 8034          1.5            20491.0
# 655           1.5            20491.0
# 10628         2.0            20491.0
#
# [2696 rows x 10 columns]

# %%
# рассчитанные значения абсолютной ошибки цены в фунтах (MAE) и ошибки в процетах (MAPE):

print(mean_absolute_error(test['price'], test['price_pred_median']))
print(mean_absolute_percentage_error(test['price'], test['price_pred_median']))


# здесь характерно то, что ошибку мы считали от медианы выборки train, 
# добавили это значение из train в выборку test
# и уже считаем ошибки (абсолютную (MAE) и в процентах (MAPE)) от цен, которые находятся в выборке test
# Out:
# 8088.543026706231
# 0.4057792506142449

# %% [markdown]
# # Алгоритм (или Модель) на основе годовых данных

# %% [markdown]
# ## На среднем значении

# %%
# Идея алгоритма (модели) - предсказываем цену машины как среднее на основе года выпуска

# %%
df = pd.read_csv('unzipped_archive/bmw.csv')
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# 4             3.0
# ...           ...
# 10776         2.0
# 10777         2.0
# 10778         2.0
# 10779         2.0
# 10780         2.0
#
# [10781 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# по умолчанию train_size = 0.75, (test = 0.25)

# по умолчанию выборки train и test получаются всегда разные при их определении, выбираются случайно

# но выборку можно захолдить, передав парамтетр random_state = 42

train, test = train_test_split(df, train_size = 0.75)

# %%
# группируем данные по годам и считаем среднюю цену для каждого года

train.groupby(['year'])['price'].agg(['mean', 'median', 'count'])
# Out:
#               mean   median  count
# year
# 1996   5995.000000   5995.0      1
# 1997   3950.000000   3950.0      1
# 1998   3950.000000   3950.0      1
# 1999   3048.333333   3950.0      3
# 2000   1624.500000   1624.5      2
# 2001   7333.333333   5950.0      3
# 2002   3733.500000   3174.5      4
# 2003   9222.500000   9222.5      2
# 2004   8021.666667   4120.0      6
# 2005   5390.166667   4685.0      6
# 2006   5767.545455   4290.0     11
# 2007   5441.000000   5200.0      9
# 2008   6519.357143   6392.5     14
# 2009   6781.095238   5995.0     21
# 2010   6988.000000   6495.0     32
# 2011   8827.358974   7990.0     39
# 2012   9682.052083   8995.0     96
# 2013  11124.782609  10298.0    253
# 2014  13387.944882  12795.0    381
# 2015  15312.714493  13999.0    690
# 2016  16754.449580  15800.0   1428
# 2017  19340.751944  18435.5   1286
# 2018  22640.665116  21302.0    645
# 2019  31136.564467  27995.0   2606
# 2020  35407.811009  32850.0    545

# %%
df1 = train.groupby(['year'])['price'].agg(['mean', 'median', 'count'])

# %%
df1.plot(marker = '+')
# Out:
# <Axes: xlabel='year'>

# %%
# интересно, что train.groupby(['year'])['price'].mean() - дает нам Series
# а если добавить .reset_index() - получаем DataFrame


train.groupby(['year'])['price'].mean().reset_index()
# Out:
#     year         price
# 0   1996   5995.000000
# 1   1997   3950.000000
# 2   1998   3950.000000
# 3   1999   3048.333333
# 4   2000   1624.500000
# 5   2001   7333.333333
# 6   2002   3733.500000
# 7   2003   9222.500000
# 8   2004   8021.666667
# 9   2005   5390.166667
# 10  2006   5767.545455
# 11  2007   5441.000000
# 12  2008   6519.357143
# 13  2009   6781.095238
# 14  2010   6988.000000
# 15  2011   8827.358974
# 16  2012   9682.052083
# 17  2013  11124.782609
# 18  2014  13387.944882
# 19  2015  15312.714493
# 20  2016  16754.449580
# 21  2017  19340.751944
# 22  2018  22640.665116
# 23  2019  31136.564467
# 24  2020  35407.811009

# %%
# задаем нашей модели (или алгоритму) переменную model_year_mean
# это наша модель - то что умеет определять целевую переменную (здесь цена) на основе каких-то параметров (здесь средняя цена)

# это модель для предсказания цены на основе срденей годовой цены:

model_year_mean = train.groupby(['year'])['price'].mean().reset_index()

# %%
# теперь столбец price - это уже не просто цена, а предсказательный атрибут. 

# Зададим ему имя price_pred_year_mean

model_year_mean.columns = ['year', 'price_pred_year_mean']

# %%
model_year_mean
# Out:
#     year  price_pred_year_mean
# 0   1996           5995.000000
# 1   1997           3950.000000
# 2   1998           3950.000000
# 3   1999           3048.333333
# 4   2000           1624.500000
# 5   2001           7333.333333
# 6   2002           3733.500000
# 7   2003           9222.500000
# 8   2004           8021.666667
# 9   2005           5390.166667
# 10  2006           5767.545455
# 11  2007           5441.000000
# 12  2008           6519.357143
# 13  2009           6781.095238
# 14  2010           6988.000000
# 15  2011           8827.358974
# 16  2012           9682.052083
# 17  2013          11124.782609
# 18  2014          13387.944882
# 19  2015          15312.714493
# 20  2016          16754.449580
# 21  2017          19340.751944
# 22  2018          22640.665116
# 23  2019          31136.564467
# 24  2020          35407.811009

# %%
# теперь можно соединить нашу модель 'model_year_mean' c выборкой 'train':

# how = 'left' - потому что мы хотим чтобы все значения в train остались в итоговом df

# средние для года 'model_year_mean' добавляются для каждой записи в train

pd.merge(train, model_year_mean, how = 'left', on = 'year')
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0            M2  2019  43480    Automatic     2689   Petrol  145  29.1
# 1            X1  2013  11995    Semi-Auto    64637   Diesel  160  51.4
# 2      5 Series  2017  23990    Semi-Auto    29283   Diesel  125  60.1
# 3      3 Series  2019  27710    Semi-Auto     9545   Diesel  145  52.3
# 4      2 Series  2019  20950       Manual     4434   Diesel  145  64.2
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080         X3  2019  30990    Semi-Auto    20423   Petrol  145  30.4
# 8081   1 Series  2008   7475       Manual    59000   Diesel  110  58.9
# 8082   1 Series  2017  13100       Manual    28850   Diesel  145  70.6
# 8083   2 Series  2017  16498    Semi-Auto    22645   Diesel  145  64.2
# 8084         X5  2019  44888    Automatic    12082   Diesel  145  37.7
#
#       engineSize  price_pred_year_mean
# 0            3.0          31136.564467
# 1            2.0          11124.782609
# 2            2.0          19340.751944
# 3            2.0          31136.564467
# 4            2.0          31136.564467
# ...          ...                   ...
# 8080         2.0          31136.564467
# 8081         2.0           6519.357143
# 8082         1.5          19340.751944
# 8083         2.0          19340.751944
# 8084         3.0          31136.564467
#
# [8085 rows x 10 columns]

# %%
# сохраняем train c новым столбцом 'model_year_mean' в переменную train (обновляем train)

train = pd.merge(train, model_year_mean, how = 'left', on = 'year')

# %%
# теперь надо посчитать ошибки (MAE и MAPE)

# %%
train['err'] = abs(train['price'] - train['price_pred_year_mean'])

# %%
# MAE:

train['err'].mean()
# Out:
# 5515.838691793659

# %%
train['err_percent'] = train['err']/train['price']

# %%
# MAPE:

train['err_percent'].mean()
# Out:
# 0.24584179555765237

# %%
# Проверка с автоматическим расчетом в sklearn:

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# для среднего:
print(mean_absolute_error(train['price'], train['price_pred_year_mean']))
print(mean_absolute_percentage_error(train['price'], train['price_pred_year_mean']))
# Out:
# 5515.838691793659
# 0.24584179555765237

# %%
# теперь ошибки MAE и MAPE надо расчитать на тестовой выборке 'test'

# для этого мы уже к 'test' добавляем нашу модель 'model_year_mean': (модель 'model_year_mean' обучена на обучающей выборке)

test = pd.merge(test, model_year_mean, how = 'left', on = 'year')

# %%
test
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 0      4 Series  2017  23475    Semi-Auto    29819   Diesel  145   50.4
# 1      3 Series  2017  15000    Automatic    36226    Other  140  148.7
# 2      2 Series  2019  20980    Semi-Auto     7494   Petrol  150   50.4
# 3      2 Series  2019  22646       Manual      123   Petrol  145   52.3
# 4            X7  2019  73990    Semi-Auto     1657   Diesel  145   31.4
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 2691         M4  2018  36440    Automatic    16000   Petrol  150   34.0
# 2692         X4  2019  38500    Semi-Auto    12733   Diesel  150   37.2
# 2693   3 Series  2017  19500    Semi-Auto     9377   Hybrid    0  134.5
# 2694   3 Series  2018  20690    Automatic    16986   Diesel  145   64.2
# 2695         X1  2014  12999    Automatic    41200   Diesel  160   52.3
#
#       engineSize  price_pred_year_mean
# 0            3.0          19340.751944
# 1            2.0          19340.751944
# 2            2.0          31136.564467
# 3            1.5          31136.564467
# 4            3.0          31136.564467
# ...          ...                   ...
# 2691         3.0          22640.665116
# 2692         3.0          31136.564467
# 2693         2.0          19340.751944
# 2694         2.0          22640.665116
# 2695         2.0          13387.944882
#
# [2696 rows x 10 columns]

# %%
# рассчитываем MAE и MAPE вручную:

test['err'] = abs(test['price'] - test['price_pred_year_mean'])

# %%
# MAE:

test['err'].mean()
# Out:
# 5397.594087052209

# %%
test['err_percent'] = test['err'] / test['price']

# %%
# MAPE:

test['err_percent'].mean()
# Out:
# 0.24772199500377876

# %%
# Проверка с автоматическим расчетом в sklearn:

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# для среднего:
print(mean_absolute_error(test['price'], test['price_pred_year_mean']))
print(mean_absolute_percentage_error(test['price'], test['price_pred_year_mean']))
# Out:
# 5397.594087052209
# 0.24772199500377876

# %%
# слабые различия MAE и MAPE на train и на test выборках показывают, что алгоритм работает стабильно

# %% [markdown]
# ## Теперь на медиане

# %%
df = pd.read_csv('unzipped_archive/bmw.csv')
df
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10776         X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# 4             3.0
# ...           ...
# 10776         2.0
# 10777         2.0
# 10778         2.0
# 10779         2.0
# 10780         2.0
#
# [10781 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split

# по умолчанию train_size = 0.75, (test = 0.25)

# по умолчанию выборки train и test получаются всегда разные при их определении, выбираются случайно

# но выборку можно захолдить, передав парамтетр random_state = 42

train, test = train_test_split(df, train_size = 0.75)

# %%
# группируем данные по годам и считаем медианную цену для каждого года

train.groupby(['year'])['price'].agg(['mean', 'median', 'count'])
# Out:
#               mean   median  count
# year
# 1996   5995.000000   5995.0      1
# 1998   3950.000000   3950.0      1
# 1999   3285.000000   3972.5      4
# 2000   1624.500000   1624.5      2
# 2001   7333.333333   5950.0      3
# 2002   5185.800000   2990.0      5
# 2004   8525.555556   4250.0      9
# 2005   4241.750000   4395.0      4
# 2006   4685.400000   3547.0     10
# 2007   4841.000000   3885.0      9
# 2008   5756.588235   5985.0     17
# 2009   6913.560000   5695.0     25
# 2010   7479.636364   6695.0     33
# 2011   9005.484848   8470.0     33
# 2012   9532.369565   8997.0     92
# 2013  11329.875912  10724.5    274
# 2014  13252.092643  12579.0    367
# 2015  15428.106509  14223.0    676
# 2016  16725.816124  15792.5   1414
# 2017  19216.121352  18298.5   1302
# 2018  22668.484945  21302.0    631
# 2019  30897.425856  27988.0   2630
# 2020  35264.646409  32850.0    543

# %%
# группируем данные по годам и считаем медианную цену для каждого года
train.groupby(['year'])['price'].median().reset_index()
# Out:
#     year    price
# 0   1996   5995.0
# 1   1998   3950.0
# 2   1999   3972.5
# 3   2000   1624.5
# 4   2001   5950.0
# 5   2002   2990.0
# 6   2004   4250.0
# 7   2005   4395.0
# 8   2006   3547.0
# 9   2007   3885.0
# 10  2008   5985.0
# 11  2009   5695.0
# 12  2010   6695.0
# 13  2011   8470.0
# 14  2012   8997.0
# 15  2013  10724.5
# 16  2014  12579.0
# 17  2015  14223.0
# 18  2016  15792.5
# 19  2017  18298.5
# 20  2018  21302.0
# 21  2019  27988.0
# 22  2020  32850.0

# %%
# даем название нашей модели (алгоритму) и присваеваем новое значение колонке с ценой 

model_pred_median = train.groupby(['year'])['price'].median().reset_index()
model_pred_median.columns = ['year', 'pred_median']
model_pred_median
# Out:
#     year  pred_median
# 0   1996       5995.0
# 1   1998       3950.0
# 2   1999       3972.5
# 3   2000       1624.5
# 4   2001       5950.0
# 5   2002       2990.0
# 6   2004       4250.0
# 7   2005       4395.0
# 8   2006       3547.0
# 9   2007       3885.0
# 10  2008       5985.0
# 11  2009       5695.0
# 12  2010       6695.0
# 13  2011       8470.0
# 14  2012       8997.0
# 15  2013      10724.5
# 16  2014      12579.0
# 17  2015      14223.0
# 18  2016      15792.5
# 19  2017      18298.5
# 20  2018      21302.0
# 21  2019      27988.0
# 22  2020      32850.0

# %%
# мержем нашу модель к train

train = pd.merge(train, model_pred_median, how = 'left', on = 'year')

# %%
train
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      1 Series  2017  14995       Manual    13472   Diesel  145  65.7
# 1            X2  2019  28150    Semi-Auto     6950   Diesel  145  58.9
# 2      1 Series  2010   2450       Manual   117454   Diesel   30  62.8
# 3      1 Series  2016  19490       Manual       10   Diesel    0  78.5
# 4      1 Series  2015  10499       Manual    23893   Diesel    0  83.1
# ...         ...   ...    ...          ...      ...      ...  ...   ...
# 8080   2 Series  2019  19190    Automatic    12790   Diesel  145  51.4
# 8081   1 Series  2015  13950       Manual    36916   Petrol  150  50.4
# 8082   5 Series  2016  12290       Manual    65747   Diesel  125  58.9
# 8083   2 Series  2018  17990    Semi-Auto    10600   Petrol  150  38.2
# 8084   5 Series  2016  15750    Automatic    59000   Diesel   30  62.8
#
#       engineSize  pred_median
# 0            2.0      18298.5
# 1            2.0      27988.0
# 2            2.0       6695.0
# 3            1.5      15792.5
# 4            1.5      14223.0
# ...          ...          ...
# 8080         2.0      27988.0
# 8081         1.6      14223.0
# 8082         2.0      15792.5
# 8083         2.0      21302.0
# 8084         2.0      15792.5
#
# [8085 rows x 10 columns]

# %%
# расчет ошибки (для каждого значения в train)

train['err'] = abs(train['price'] - train['pred_median'])

# %%
# расчет метрики MAE:

train['err'].mean()
# Out:
# 5183.811502782932

# %%
# расчет процентной ошибки (для каждого значения в train):

train['err_percent'] = train['err'] / train['price']

# %%
# расчет метрики MAPE:

train['err_percent'].mean()
# Out:
# 0.21607957207609332

# %%
# Проверка с автоматическим расчетом в sklearn:

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# для среднего:
print(mean_absolute_error(train['price'], train['pred_median']))
print(mean_absolute_percentage_error(train['price'], train['pred_median']))
# Out:
# 5183.811502782932
# 0.21607957207609332

# %%
# проверим на тестовой выборке:

# %%
test
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 4585   8 Series  2020  59995    Semi-Auto     1501   Petrol  145   31.7
# 9178         X1  2012   7999       Manual    88706   Diesel  160   51.4
# 2562   1 Series  2019  29490    Semi-Auto     7656   Petrol  150   34.5
# 1570   3 Series  2018  18300    Automatic    30214   Diesel  145   62.8
# 208    1 Series  2017  14498       Manual    20790   Diesel  145   70.6
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 3855   2 Series  2019  21980       Manual     9326   Diesel  145   60.1
# 4982         X2  2020  28995    Semi-Auto       10   Diesel  145   58.9
# 5759   4 Series  2014  18062    Semi-Auto    49745   Diesel  165   50.4
# 5296         Z4  2019  27450    Semi-Auto     7363   Petrol  145   38.2
# 8412   3 Series  2016  14887    Automatic    45716   Hybrid    0  134.5
#
#       engineSize
# 4585         3.0
# 9178         2.0
# 2562         2.0
# 1570         2.0
# 208          1.5
# ...          ...
# 3855         2.0
# 4982         2.0
# 5759         3.0
# 5296         2.0
# 8412         2.0
#
# [2696 rows x 9 columns]

# %%
# мержим нашу модель к тестовой выборке:

# Проверка с автоматическим расчетом в sklearn не работает естли в test есть nan - без dropna() - не работает.
# однако в ручном режиме nan игнорируется.
# результаты в обоих случаях сходятся.

test = pd.merge(test, model_pred_median, how = 'left', on = 'year').dropna()

# %%
test
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 0      8 Series  2020  59995    Semi-Auto     1501   Petrol  145   31.7
# 1            X1  2012   7999       Manual    88706   Diesel  160   51.4
# 2      1 Series  2019  29490    Semi-Auto     7656   Petrol  150   34.5
# 3      3 Series  2018  18300    Automatic    30214   Diesel  145   62.8
# 4      1 Series  2017  14498       Manual    20790   Diesel  145   70.6
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 2688   2 Series  2019  21980       Manual     9326   Diesel  145   60.1
# 2689         X2  2020  28995    Semi-Auto       10   Diesel  145   58.9
# 2690   4 Series  2014  18062    Semi-Auto    49745   Diesel  165   50.4
# 2691         Z4  2019  27450    Semi-Auto     7363   Petrol  145   38.2
# 2692   3 Series  2016  14887    Automatic    45716   Hybrid    0  134.5
#
#       engineSize  pred_median_x      err  err_percent  pred_median_y  \
# 0            3.0        32850.0  27145.0     0.452454        32850.0
# 1            2.0         8997.0    998.0     0.124766         8997.0
# 2            2.0        27988.0   1502.0     0.050933        27988.0
# 3            2.0        21302.0   3002.0     0.164044        21302.0
# 4            1.5        18298.5   3800.5     0.262140        18298.5
# ...          ...            ...      ...          ...            ...
# 2688         2.0        27988.0   6008.0     0.273339        27988.0
# 2689         2.0        32850.0   3855.0     0.132954        32850.0
# 2690         3.0        12579.0   5483.0     0.303565        12579.0
# 2691         2.0        27988.0    538.0     0.019599        27988.0
# 2692         2.0        15792.5    905.5     0.060825        15792.5
#
#       pred_median
# 0         32850.0
# 1          8997.0
# 2         27988.0
# 3         21302.0
# 4         18298.5
# ...           ...
# 2688      27988.0
# 2689      32850.0
# 2690      12579.0
# 2691      27988.0
# 2692      15792.5
#
# [2693 rows x 14 columns]

# %%
test[test['pred_median'].isna()]
# Out:
# Empty DataFrame
# Columns: [model, year, price, transmission, mileage, fuelType, tax, mpg, engineSize, pred_median_x, err, err_percent, pred_median_y, pred_median]
# Index: []

# %%
# считаем ошибку для каждого значения в тестовой выборке:

test['err'] = abs(test['price'] - test['pred_median'])

# %%
# считаем MAE:

test['err'].mean()
# Out:
# 5388.604530263647

# %%
# считаем ошибку в процентах для каждого значения в тестовой выборке:

test['err_percent'] = test['err'] / test['price']

# %%
# считаем MAPE:

test['err_percent'].mean()
# Out:
# 0.2209693691636021

# %%
# Проверка с автоматическим расчетом в sklearn: (работает если дропнуть nan - несколько шагов назад)

from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# для медианы:
print(mean_absolute_error(test['price'], test['pred_median']))
print(mean_absolute_percentage_error(test['price'], test['pred_median']))
# Out:
# 5388.604530263647
# 0.2209693691636021
